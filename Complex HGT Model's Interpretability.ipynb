# %% [markdown]
# # **Interpretability of the Best-Performing Model $\rightarrow$ Complex HGT Model**
#
# ### Complex HGT Model (Best) vs. xG Model (Worst)

# %%
# Import the Thesis' Complex HGT Functions Module

import Thesis_Interpretability_of_Best_Model_Functions as TIBMFs

# %% [markdown]
# ___
#
# ### Extract Shot Frames In Which There Is Largest Discrepancy Between the Best-Performing (Complex HGT) & Worst-Peroforming (xG) Models In Predicting Goals (Scored-Shots, i.e. the Minority Class)

# %%
Test_Data_df = TIBMFs.Browse_Appropriate_Hold_Out_Test_Dataset_File(  )


print(Test_Data_df.shape, "\n")

Test_Data_df
# Out:
#  Select the (Un-Preprocessed) Hold-Out Test `.parquet` File
#
# (2416, 697)
#            X       Y      Z      X1      X2      X3      X4      X5      X6  \
# 5412  4357.0  1362.0  200.0  2910.0 -1464.0 -2056.0  -673.0 -1403.0 -4586.0
# 4642  3396.0   258.0   30.0  2924.0 -1328.0 -1979.0 -3465.0 -3708.0 -3448.0
# 7652  4321.0   291.0   45.0  4440.0  -695.0  -190.0  -665.0   955.0  1464.0
# 589   2842.0  1571.0   89.0  4995.0  2226.0  3913.0  3134.0   268.0  3611.0
# 7214  4748.0  1798.0  447.0  1954.0 -3196.0 -4080.0 -4207.0 -4997.0 -4253.0
# ...      ...     ...    ...     ...     ...     ...     ...     ...     ...
# 450   4869.0  -446.0   69.0  4917.0  1475.0  2001.0  4563.0  2813.0  4690.0
# 210   4748.0   928.0   82.0 -3181.0  2363.0  4551.0   187.0   724.0  3862.0
# 2332  4207.0 -2242.0   23.0 -2714.0  2626.0  4218.0  4104.0  2083.0  1174.0
# 3079  4585.0 -1082.0   55.0  4503.0  4431.0  3755.0  4568.0  2991.0  4444.0
# ...

# %%
Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals = TIBMFs.Browse_Appropriate_Files_and_Extract_Shot_Frames_With_Largest_Discrepancy_Between_Models_Predicting_Goals_3( top_K_discrepancies = 5 )


print(Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.shape, "\n")

Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals
# Out:
#  Select the (Un-Preprocessed) Hold-Out Test `.parquet` File and the `.csv` Files for the HGT & xG Models
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\3196411143.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["Probability_Difference"] = abs( filtered_df["HGT Model Test Class Labels' Predicted Probabilities"] - filtered_df["xG Model Test Class Labels' Predicted Probabilities"] )
# (5, 703)
#       Will_Be_a_Goal  HGT Model Test Class Labels' Predicted Probabilities  \
# 2149               1                                           0.955115
# 1723               1                                           0.910692
# 1086               1                                           0.921653
# ...

# %% [markdown]
# ___
#
# ### Plot These Extracted Shots On the Pitch

# %%
TIBMFs.Plot_Static_Shot_Frame( shot_frame_tracking_data_row = Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.iloc[0], team_colors = ("b", "r"), 
                               home_team_players_color_and_style = "bo", away_team_players_color_and_style = "ro", 
                               ball_color_and_style = "ko",
                               include_player_velocities = True, include_ball_velocity = False,
                               player_marker_size = 10, player_alpha = 0.7, 
                               show_kit_numbers = True, kit_numbers_on_player_or_next_to_player = "on player", 
                               figax = None, metric_unit = "cm", pitch_color = "green", style_of_the_goals = "entire_goal" );
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\1501523056.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_row["Z"] = abs(data_row["Z"]) if data_row["Z"] < 0 else data_row["Z"]

# %%
TIBMFs.Plot_Static_Shot_Frame( shot_frame_tracking_data_row = Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.iloc[1], team_colors = ("b", "r"), 
                               home_team_players_color_and_style = "bo", away_team_players_color_and_style = "ro", 
                               ball_color_and_style = "ko",
                               include_player_velocities = True, include_ball_velocity = False,
                               player_marker_size = 10, player_alpha = 0.7, 
                               show_kit_numbers = True, kit_numbers_on_player_or_next_to_player = "on player", 
                               figax = None, metric_unit = "cm", pitch_color = "green", style_of_the_goals = "entire_goal" );
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\1501523056.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_row["Z"] = abs(data_row["Z"]) if data_row["Z"] < 0 else data_row["Z"]

# %%
TIBMFs.Plot_Static_Shot_Frame( shot_frame_tracking_data_row = Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.iloc[2], team_colors = ("b", "r"), 
                               home_team_players_color_and_style = "bo", away_team_players_color_and_style = "ro", 
                               ball_color_and_style = "ko",
                               include_player_velocities = True, include_ball_velocity = False,
                               player_marker_size = 10, player_alpha = 0.7, 
                               show_kit_numbers = True, kit_numbers_on_player_or_next_to_player = "on player", 
                               figax = None, metric_unit = "cm", pitch_color = "green", style_of_the_goals = "entire_goal" );
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\1501523056.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_row["Z"] = abs(data_row["Z"]) if data_row["Z"] < 0 else data_row["Z"]

# %%
TIBMFs.Plot_Static_Shot_Frame( shot_frame_tracking_data_row = Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.iloc[3], team_colors = ("b", "r"), 
                               home_team_players_color_and_style = "bo", away_team_players_color_and_style = "ro", 
                               ball_color_and_style = "ko",
                               include_player_velocities = True, include_ball_velocity = False,
                               player_marker_size = 10, player_alpha = 0.7, 
                               show_kit_numbers = True, kit_numbers_on_player_or_next_to_player = "on player", 
                               figax = None, metric_unit = "cm", pitch_color = "green", style_of_the_goals = "entire_goal" );
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\1501523056.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_row["Z"] = abs(data_row["Z"]) if data_row["Z"] < 0 else data_row["Z"]

# %%
TIBMFs.Plot_Static_Shot_Frame( shot_frame_tracking_data_row = Top_5_Discrepancies_HGT_vs_xG_In_Predicting_Goals.iloc[4], team_colors = ("b", "r"), 
                               home_team_players_color_and_style = "bo", away_team_players_color_and_style = "ro", 
                               ball_color_and_style = "ko",
                               include_player_velocities = True, include_ball_velocity = False,
                               player_marker_size = 10, player_alpha = 0.7, 
                               show_kit_numbers = True, kit_numbers_on_player_or_next_to_player = "on player", 
                               figax = None, metric_unit = "cm", pitch_color = "green", style_of_the_goals = "entire_goal" );
# Out:
# C:\Users\Pedro\AppData\Local\Temp\ipykernel_27772\1501523056.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_row["Z"] = abs(data_row["Z"]) if data_row["Z"] < 0 else data_row["Z"]
